# %% [raw]
# ---
# title: quarto demo
# execute:
#     echo: false
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#| label: fig-sin
#| fig-cap: test figure

x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x,y)
plt.show()
